# %% [markdown]
# # Data wrangling<a id='1_Data_wrangling'></a>

# %% [markdown]
# ## Imports<a id='1.1_Imports'></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# ## Joining Data<a id='1.2_Joining Data'></a>

# %%
# Specify the directory containing the CSV files
csv_directory = "C:/Users/harry/Springboard/Capstone 2"

# Define the main file and initialize the base dataframe
main_file = "ripa_stops_historic.csv"
main_df = pd.read_csv(os.path.join(csv_directory, main_file))

# Loop through all other CSV files and merge them with the main file
for file in os.listdir(csv_directory):
    if file.endswith(".csv") and file != main_file:
        # Read the current CSV file
        current_df = pd.read_csv(os.path.join(csv_directory, file))

        # Drop duplicate uids in the merging dataset
        current_df = current_df.drop_duplicates(subset="uid")

        # Remove repetitive columns (e.g., 'stop_id', 'ripa_stop_reason_historic_stop_id') from current_df
        columns_to_remove = [col for col in current_df.columns if col.startswith('ripa_') and '_stop_id' in col]
        current_df = current_df.drop(columns=columns_to_remove, errors='ignore')
        columns_to_remove = [col for col in current_df.columns if col.startswith('ripa_') and '_pid' in col]
        current_df = current_df.drop(columns=columns_to_remove, errors='ignore')

        # Rename columns (except 'uid') to avoid conflicts
        current_df = current_df.rename(
            columns={col: f"{file.split('.')[0]}_{col}" for col in current_df.columns if col != "uid"}
        )

        # Merge the current dataframe with the main dataframe on 'uid'
        main_df = pd.merge(main_df, current_df, on="uid", how="left")

# Save the merged dataframe to a new CSV file
output_file = os.path.join(csv_directory, "merged_ripa_dataset.csv")
main_df.to_csv(output_file, index=False)

print(f"Merged dataset saved to: {output_file}")
# Out:
# C:\Users\harry\AppData\Local\Temp\ipykernel_35720\2496063963.py:6: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   main_df = pd.read_csv(os.path.join(csv_directory, main_file))
# C:\Users\harry\AppData\Local\Temp\ipykernel_35720\2496063963.py:12: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   current_df = pd.read_csv(os.path.join(csv_directory, file))
# Merged dataset saved to: C:/Users/harry/Springboard/Capstone 2\merged_ripa_dataset.csv

# %% [markdown]
# ## Exploring Data<a id='1.2_Exploring Data'></a>

# %%
main_df.columns
# Out:
# Index(['uid', 'stop_id', 'ori', 'agency', 'exp_years', 'date_stop',
#        'time_stop', 'stopduration', 'stop_in_response_to_cfs',
#        'officer_assignment_key', 'assignment', 'intersection', 'address_block',
#        'land_mark', 'address_street', 'highway_exit', 'isschool',
#        'school_name', 'address_city', 'beat', 'beat_name', 'pid', 'isstudent',
#        'perceived_limited_english', 'perceived_age', 'perceived_gender',
#        'gender_nonconforming', 'perceived_lgbt',
#        'ripa_actions_taken_historic_stop_id',
#        'ripa_actions_taken_historic_pid', 'ripa_actions_taken_historic_action',
#        'ripa_actions_taken_historic_person_search_consented',
#        'ripa_actions_taken_historic_property_search_consented',
#        'ripa_contraband_evid_historic_stop_id',
#        'ripa_contraband_evid_historic_pid',
#        'ripa_contraband_evid_historic_contraband',
#        'ripa_disability_historic_stop_id', 'ripa_disability_historic_pid',
#        'ripa_disability_historic_disability', 'ripa_gender_historic_stop_id',
#        'ripa_gender_historic_pid', 'ripa_gender_historic_gender',
#        'ripa_prop_seize_basis_historic_stop_id',
#        'ripa_prop_seize_basis_historic_pid',
#        'ripa_prop_seize_basis_historic_basisforpropertyseizure',
#        'ripa_prop_seize_type_historic_stop_id',
#        'ripa_prop_seize_type_historic_pid',
#        'ripa_prop_seize_type_historic_type_of_property_seized',
#        'ripa_race_historic_stop_id', 'ripa_race_historic_pid',
#        'ripa_race_historic_race', 'ripa_search_basis_historic_stop_id',
#        'ripa_search_basis_historic_pid',
#        'ripa_search_basis_historic_basis_for_search',
#        'ripa_search_basis_historic_basis_for_search_explanation',
#        'ripa_stop_reason_historic_stop_id', 'ripa_stop_reason_historic_pid',
#        'ripa_stop_reason_historic_reason_for_stop',
#        'ripa_stop_reason_historic_reason_for_stopcode',
#        'ripa_stop_reason_historic_reason_for_stop_code_text',
#        'ripa_stop_reason_historic_reason_for_stop_detail',
#        'ripa_stop_reason_historic_reason_for_stop_explanation',
#        'ripa_stop_result_historic_stop_id', 'ripa_stop_result_historic_pid',
#        'ripa_stop_result_historic_resultkey',
#        'ripa_stop_result_historic_result', 'ripa_stop_result_historic_code',
#        'ripa_stop_result_historic_resulttext'],
#       dtype='object')

# %%
columns_to_remove = [col for col in main_df.columns if col.startswith('ripa_') and col.endswith('_stop_id')]
main_df = main_df.drop(columns=columns_to_remove, errors='ignore')
columns_to_remove = [col for col in main_df.columns if col.startswith('ripa_') and col.endswith('_pid')]
main_df = main_df.drop(columns=columns_to_remove, errors='ignore')

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 755891 entries, 0 to 755890
# Data columns (total 48 columns):
#  #   Column                                                   Non-Null Count   Dtype
# ---  ------                                                   --------------   -----
#  0   uid                                                      755891 non-null  object
#  1   stop_id                                                  755891 non-null  int64
#  2   ori                                                      755891 non-null  object
#  3   agency                                                   755891 non-null  object
#  4   exp_years                                                755891 non-null  int64
#  5   date_stop                                                755891 non-null  object
#  6   time_stop                                                755891 non-null  object
#  7   stopduration                                             755891 non-null  int64
#  8   stop_in_response_to_cfs                                  755891 non-null  int64
#  9   officer_assignment_key                                   755891 non-null  int64
#  10  assignment                                               755891 non-null  object
#  11  intersection                                             82680 non-null   object
#  12  address_block                                            667817 non-null  float64
#  13  land_mark                                                135 non-null     object
#  14  address_street                                           722596 non-null  object
#  15  highway_exit                                             6614 non-null    object
#  16  isschool                                                 755891 non-null  int64
#  17  school_name                                              489 non-null     object
#  18  address_city                                             755888 non-null  object
#  19  beat                                                     755890 non-null  float64
#  20  beat_name                                                755890 non-null  object
#  21  pid                                                      755891 non-null  int64
#  22  isstudent                                                755891 non-null  int64
#  23  perceived_limited_english                                755891 non-null  int64
#  24  perceived_age                                            755891 non-null  int64
#  25  perceived_gender                                         755637 non-null  object
#  26  gender_nonconforming                                     755881 non-null  float64
#  27  perceived_lgbt                                           755881 non-null  object
#  28  ripa_actions_taken_historic_action                       300971 non-null  object
#  29  ripa_actions_taken_historic_person_search_consented      17879 non-null   object
#  30  ripa_actions_taken_historic_property_search_consented    17879 non-null   object
#  31  ripa_contraband_evid_historic_contraband                 66936 non-null   object
#  32  ripa_disability_historic_disability                      33388 non-null   object
#  33  ripa_gender_historic_gender                              755642 non-null  object
#  34  ripa_prop_seize_basis_historic_basisforpropertyseizure   16584 non-null   object
#  35  ripa_prop_seize_type_historic_type_of_property_seized    16729 non-null   object
#  36  ripa_race_historic_race                                  755891 non-null  object
#  37  ripa_search_basis_historic_basis_for_search              160536 non-null  object
#  38  ripa_search_basis_historic_basis_for_search_explanation  126272 non-null  object
#  39  ripa_stop_reason_historic_reason_for_stop                755891 non-null  object
#  40  ripa_stop_reason_historic_reason_for_stopcode            722118 non-null  object
#  41  ripa_stop_reason_historic_reason_for_stop_code_text      722118 non-null  object
#  42  ripa_stop_reason_historic_reason_for_stop_detail         722128 non-null  object
#  43  ripa_stop_reason_historic_reason_for_stop_explanation    755889 non-null  object
#  44  ripa_stop_result_historic_resultkey                      755891 non-null  int64
#  45  ripa_stop_result_historic_result                         755512 non-null  object
#  46  ripa_stop_result_historic_code                           450954 non-null  float64
#  47  ripa_stop_result_historic_resulttext                     450954 non-null  object
# dtypes: float64(4), int64(11), object(33)
# memory usage: 276.8+ MB

# %%
main_df.head()
# Out:
#   uid  stop_id        ori agency  exp_years   date_stop time_stop  \
# 0  1b        1  CA0371100   SDPD          1  2023-11-27  23:58:00
# 1  2b        2  CA0371100   SDPD          3  2023-11-27  23:49:00
# 2  3b        3  CA0371100   SDPD          1  2023-11-27  23:47:00
# 3  4b        4  CA0371100   SDPD          4  2023-11-27  23:47:00
# 4  5b        5  CA0371100   SDPD          3  2023-11-27  23:42:00
#
#    stopduration  stop_in_response_to_cfs  officer_assignment_key  ...  \
# 0            10                        0                       1  ...
# 1            10                        0                       1  ...
# 2            15                        0                       1  ...
# 3            45                        1                       1  ...
# 4             5                        0                       1  ...
#
#   ripa_search_basis_historic_basis_for_search_explanation  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3          subject was searched after being arrested
# 4                                                NaN
#
#   ripa_stop_reason_historic_reason_for_stop  \
# 0                         Traffic Violation
# 1                         Traffic Violation
# 2                         Traffic Violation
# 3                      Reasonable Suspicion
# 4                         Traffic Violation
#
#    ripa_stop_reason_historic_reason_for_stopcode  \
# 0                                        66551.0
# 1                                        54303.0
# 2                                        54098.0
# 3                                        13174.0
# 4                                        54306.0
#
#   ripa_stop_reason_historic_reason_for_stop_code_text  \
# 0  26508(H) VC - AIR BRAKE HAZARD HWY VIOL (I) 66551
# 1    22349(A) VC - EXCEED SPEED ON HIGHWAY (I) 54303
# 2  21453(A) VC - FAIL STOP LINE/ETC AT RED (I) 54098
# 3  243(E)(1) PC - BAT:SPOUSE/EX SP/DATE/ETC (M) 1...
# 4       22400(A) VC - DRIVE TOO SLOWLY/ETC (I) 54306
#
#   ripa_stop_reason_historic_reason_for_stop_detail  \
# 0                                 Moving Violation
# 1                                 Moving Violation
# 2                                 Moving Violation
# 3                      Matched suspect description
# 4                                 Moving Violation
#
#   ripa_stop_reason_historic_reason_for_stop_explanation  \
# 0                                           as above
# 1                                     PUBLIC OFFENSE
# 2  vehicle failed to stop at limit line of red tr...
# 3                subject matched suspect description
# 4                                     PUBLIC OFFENSE
#
#    ripa_stop_result_historic_resultkey  ripa_stop_result_historic_result  \
# 0                                    3           Citation for infraction
# 1                                    3           Citation for infraction
# 2                                    2       Warning (verbal or written)
# 3                                    6  Custodial Arrest without warrant
# 4                                    2       Warning (verbal or written)
#
#   ripa_stop_result_historic_code  \
# 0                        42127.0
# 1                        54303.0
# 2                        54098.0
# 3                        13174.0
# 4                        54306.0
#
#                 ripa_stop_result_historic_resulttext
# 0          12500(A) VC - DRIVE W/O LICENSE (I) 42127
# 1    22349(A) VC - EXCEED SPEED ON HIGHWAY (I) 54303
# 2  21453(A) VC - FAIL STOP LINE/ETC AT RED (I) 54098
# 3  243(E)(1) PC - BAT:SPOUSE/EX SP/DATE/ETC (M) 1...
# 4       22400(A) VC - DRIVE TOO SLOWLY/ETC (I) 54306
#
# [5 rows x 48 columns]

# %%
missing = pd.concat([main_df.isnull().sum(), 100 * main_df.isnull().mean()], axis=1)
missing.columns = ['count', '%']
missing.sort_values(by='count', ascending=False)
# Out:
#                                                      count          %
# land_mark                                           755756  99.982140
# school_name                                         755402  99.935308
# highway_exit                                        749277  99.125006
# ripa_prop_seize_basis_historic_basisforproperty...  739307  97.806033
# ripa_prop_seize_type_historic_type_of_property_...  739162  97.786850
# ripa_actions_taken_historic_property_search_con...  738012  97.634712
# ripa_actions_taken_historic_person_search_conse...  738012  97.634712
# ripa_disability_historic_disability                 722503  95.582961
# ripa_contraband_evid_historic_contraband            688955  91.144755
# intersection                                        673211  89.061915
# ripa_search_basis_historic_basis_for_search_exp...  629619  83.294946
# ripa_search_basis_historic_basis_for_search         595355  78.762017
# ripa_actions_taken_historic_action                  454920  60.183280
# ripa_stop_result_historic_resulttext                304937  40.341398
# ripa_stop_result_historic_code                      304937  40.341398
# address_block                                        88074  11.651680
# ripa_stop_reason_historic_reason_for_stop_code_...   33773   4.467972
# ripa_stop_reason_historic_reason_for_stopcode        33773   4.467972
# ripa_stop_reason_historic_reason_for_stop_detail     33763   4.466649
# address_street                                       33295   4.404736
# ripa_stop_result_historic_result                       379   0.050140
# perceived_gender                                       254   0.033603
# ripa_gender_historic_gender                            249   0.032941
# gender_nonconforming                                    10   0.001323
# perceived_lgbt                                          10   0.001323
# address_city                                             3   0.000397
# ripa_stop_reason_historic_reason_for_stop_expla...       2   0.000265
# beat                                                     1   0.000132
# beat_name                                                1   0.000132
# ripa_race_historic_race                                  0   0.000000
# ripa_stop_reason_historic_reason_for_stop                0   0.000000
# ripa_stop_result_historic_resultkey                      0   0.000000
# uid                                                      0   0.000000
# stop_id                                                  0   0.000000
# perceived_limited_english                                0   0.000000
# isstudent                                                0   0.000000
# pid                                                      0   0.000000
# isschool                                                 0   0.000000
# assignment                                               0   0.000000
# officer_assignment_key                                   0   0.000000
# stop_in_response_to_cfs                                  0   0.000000
# stopduration                                             0   0.000000
# time_stop                                                0   0.000000
# date_stop                                                0   0.000000
# exp_years                                                0   0.000000
# agency                                                   0   0.000000
# ori                                                      0   0.000000
# perceived_age                                            0   0.000000
